# %% [markdown]
# # Crea un modelo de Regresión Lineal Simple para predecir los gastos según los ingresos de la ferreteria

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ingre_df = pd.read_csv('/content/drive/MyDrive/2026/ECBD/U3 Aprendizaje supervisado/gastos_ingresos_ferreteria.csv')

# %%
ingre_df.head(10)
# Out:
#    gastos  ingresos
# 0     609     53712
# 1     171     29833
# 2    1819    103134
# 3    1724     98856
# 4    1268     66690
# 5     794     71097
# 6     208     57520
# 7     804     70750
# 8     205     37903
# 9    1324     82141

# %%
import seaborn as sb

sb.scatterplot(x="ingresos", y="gastos", data=ingre_df,
               hue="ingresos", palette="coolwarm")
# Out:
# <Axes: xlabel='ingresos', ylabel='gastos'>

# %% [markdown]
# # #PASO 2 DETERMINAR LAS CARACTERISTICAS

# %%
#PASO 2 DETERMINAR LAS CARACTERISTICAS
X=ingre_df['ingresos']  #FUNCION LINEAL Y=A-BX-46
Y=ingre_df['gastos']
X_procesada=X.values.reshape((-1,1))
Y_procesada=Y.values.reshape((-1,1))

# %%
print(X)
#print(X_procesada)

# %% [markdown]
# # #PASO 3 DIVIDIR LOS DATOS EN ENTRENAMIENTO Y DATOS DE PRUEBA

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# En este ejemplo, tenemos un conjunto de datos con 200 muestras, utilizamos train_test_split de sklearn.model_selection para dividir los datos en conjuntos de entrenamiento y prueba, con un tamaño de datos de prueba del 20 % (test_size=0.2). Finalmente, imprimimos las formas de los conjuntos de entrenamiento y prueba para verificar los tamaños de las divisiones.

# %%
#PASO 3 DIVIDIR LOS DATOS EN ENTRENAMIENTO Y DATOS DE PRUEBA
from sklearn.model_selection import train_test_split
# Split the dataset into training and testing sets  test_size=0.2 el 20% para datos de prueba
X_train, X_test, y_train, y_test = train_test_split(X_procesada, Y_procesada, test_size=0.2, random_state=42)

# Print the shapes of the training and testing sets
print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (160, 1) (160, 1)
# Testing set shape: (40, 1) (40, 1)

# %% [markdown]
# # #PASO 4 CREAR EL MODELO

# %%
#PASO 4 CREAR EL MODELO
from sklearn.linear_model import LinearRegression
modelo_RL_simple=LinearRegression()

# %% [markdown]
# # 5.	Entrena el modelo con la función fit

# %%
modelo_RL_simple.fit(X_train,y_train)  #FUNCION FIT para entrenar el modelo
# Out:
# LinearRegression()

# %%
ingresos_futuro=X_test[0]
print(f'ingresos_futuro{ingresos_futuro}')
# Out:
# ingresos_futuro[66628]

# %% [markdown]
# # 6.	Utiliza el modelo para realizar la predicción, mediante la función predict

# %%
#ingresos_futuro=[66628
predicc=modelo_RL_simple.predict([ingresos_futuro])
print(f'prediccion de gasto mensual{predicc}')
# Out:
# prediccion de gasto mensual[[915.12241796]]

# %%
prediccion=modelo_RL_simple.predict(X_test)
print(prediccion)
# Out:
# [[ 915.12241796]
#  [1274.85793005]
#  [2101.85130167]
#  [1619.81953426]
#  [ 461.58173562]
#  [ 339.63094995]
#  [ 317.84604039]
#  [1328.24315151]
#  [1182.59721234]
#  [ 489.68670756]
#  [ 395.06866755]
#  [ 238.32705616]
#  [1198.81396404]
#  [ 773.80501026]
#  [1250.49215901]
#  [ 910.04198196]
#  [ 749.98792631]
#  [1273.84184285]
#  [1486.81371985]
#  [ 546.91273863]
#  [1534.95593136]
#  [ 383.38366475]
#  [ 869.27656352]
#  [  32.65068525]
#  [ 667.84743711]
#  [ 242.28979624]
#  [1716.67296611]
#  [1403.41328252]
#  [1307.57593787]
#  [ 382.81465592]
#  [1230.37363246]
#  [ 427.58345793]
#  [ 668.25387199]
#  [1567.65361744]
#  [ 917.0326619 ]
#  [1187.84022229]
#  [ 593.06341923]
#  [1068.75480252]
#  [ 618.42495573]
#  [1104.9681503 ]]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(ingre_df['ingresos'], ingre_df['gastos'], 'o')
plt.plot(ingre_df['ingresos'], modelo_RL_simple.predict(X_procesada), '-')
plt.xlabel('ingresos')
plt.ylabel('gastos')
# Out:
# Text(0, 0.5, 'gastos')

# %%
 #Si el valor se acerca a cero la relación entre las variables independientes y la variable dependiente es muy débil o inexistente.
modelo_RL_simple.score(X_train,y_train)
# Out:
# 0.6057178145242592

# %%
modelo_RL_simple.score(X_test,y_test)
# Out:
# 0.7656871544250538

# %% [markdown]
# # 7.	evalúa el modelo. Calcula el error cuadrático medio

# %%
# evalua el modelo
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Make predictions on the testing set
y_pred = modelo_RL_simple.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)

# %%
# Print the evaluation metrics
print('Mean Squared Error:', mse)
print(f'Root Mean Squared Error: {rmse:.2f}')
# Out:
# Mean Squared Error: 97339.73004886803
# Root Mean Squared Error: 97339.73
